# %%
##LINEAR REGRESSION
##2019331076

import matplotlib.pyplot as plt
from prettytable import PrettyTable


def linear_regression(x,y):
    
    myTable = PrettyTable(['x', 'y', 'x\N{SUPERSCRIPT TWO}', 'xy'])
    
    sum_x = 0
    
    sum_y = 0
    
    x_sq  = 0
    
    xy    = 0
    
    
    n = len(x)
    
    for i in  range(n):
        
        sum_x += x [ i ]
        
        sum_y += y [ i ]
        
        x_sq  += ( x[ i ] * x[ i ] )
        
        xy    += x[ i ] * y[ i ]
        
        myTable.add_row([x[i], y[i], round(x[i]**2, 6), round(x[i]*y[i], 6)])
        
    
    a1 = ( n * xy ) - ( sum_x * sum_y )
    
    b = ( n * x_sq ) - ( sum_x * sum_x )
    
    a1 /= (1.00 * b)
    
    x_mean = sum_x / ( n * 1.00 )
    
    y_mean = sum_y / ( n * 1.00 )
    
    a0 = y_mean - ( a1 * x_mean )
    
    
    plt.scatter(x,y)
    
    print(myTable)
    
    print("Linear Regression Line of the given data is \n")
    
    print('y = (%.3f) + (%.3f)x' % (a0, a1))
    
    plt.xlabel("X")
    
    plt.ylabel("Y")
    
    plt.title("Linear Regression Model")
        
    y_val = []
    
    for i in range(n):
        
        y_val.append(a0 + a1*x[i])
    
    
    
    plt.plot(x,y_val,color="g")

    plt.show()           






number_of_data_points = int(input("Enter the number of data points you are about to give\n"))

print("Enter the data points x f(x) format seperated by space")

x=[]

y=[]


for i in range(0,number_of_data_points):
    
    data = input(" x f(x) {} : ".format(i+1)).split()
    
    x.append(float(data[0]))
    y.append(float(data[1]))
    
linear_regression(x,y)
# Out:
# Enter the number of data points you are about to give
# 8
# Enter the data points x f(x) format seperated by space
#  x f(x) 1 : 22 18.4
#  x f(x) 2 : 18 19.2
#  x f(x) 3 : 30 14.5
#  x f(x) 4 : 16 19.0
#  x f(x) 5 : 25 16.6
#  x f(x) 6 : 20 17.7
#  x f(x) 7 : 10 24.4
#  x f(x) 8 : 14 21.0
# +------+------+-------+-------+
# |  x   |  y   |   x²  |   xy  |
# +------+------+-------+-------+
# | 22.0 | 18.4 | 484.0 | 404.8 |
# | 18.0 | 19.2 | 324.0 | 345.6 |
# | 30.0 | 14.5 | 900.0 | 435.0 |
# | 16.0 | 19.0 | 256.0 | 304.0 |
# | 25.0 | 16.6 | 625.0 | 415.0 |
# | 20.0 | 17.7 | 400.0 | 354.0 |
# | 10.0 | 24.4 | 100.0 | 244.0 |
# | 14.0 | 21.0 | 196.0 | 294.0 |
# +------+------+-------+-------+
# Linear Regression Line of the given data is
#
# y = (27.466) + (-0.445)x
